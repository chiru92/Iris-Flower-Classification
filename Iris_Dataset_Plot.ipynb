# %% [markdown]
# <a href="https://colab.research.google.com/github/chiru92/Iris-Flower-Classification/blob/master/Iris_Dataset_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # **Read Iris Dataset and View it's details**

# %%
iris = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Iris.csv")

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris = iris.drop("Id", axis=1)

# %%
iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# # **2D Scatter Plot**

# %%
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")
plt.show()

# %%
sn.set_style("whitegrid")
sn.FacetGrid(iris, hue="Species", size=5) \
  .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
  .add_legend();
plt.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # **3D Scatter Plot**

# %%
plt.close()
sn.set_style("whitegrid");
sn.pairplot(iris, hue="Species", size=3, diag_kind="kde")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #**Histogram, PDF (Probability Density Function), CDF (Cumulative Distribution Function)**

# %%
iris_satosa = iris.loc[iris["Species"] == "Iris-setosa"]
iris_virginica = iris.loc[iris["Species"] == "Iris-virginica"]
iris_versicolor = iris.loc[iris["Species"] == "Iris-versicolor"]

plt.plot(iris_satosa["PetalLengthCm"], np.zeros_like(iris_satosa["PetalLengthCm"]))
plt.plot(iris_virginica["PetalLengthCm"], np.zeros_like(iris_virginica["PetalLengthCm"]))
plt.plot(iris_versicolor["PetalLengthCm"], np.zeros_like(iris_versicolor["PetalLengthCm"]))

plt.show()

# %%
sn.FacetGrid(iris, hue="Species", size=5) \
  .map(sn.distplot, "PetalLengthCm") \
  .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sn.FacetGrid(iris, hue="Species", size=5) \
  .map(sn.distplot, "PetalWidthCm") \
  .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sn.FacetGrid(iris, hue="Species", size=5) \
  .map(sn.distplot, "SepalLengthCm") \
  .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sn.FacetGrid(iris, hue="Species", size=5) \
  .map(sn.distplot, "SepalWidthCm") \
  .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
counts, bin_edges = np.histogram(iris_satosa["PetalLengthCm"], bins=10, density=True)

pdf = counts/sum(counts)
print(pdf)
print("*************************************")
print(bin_edges)

cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# *************************************
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %% [markdown]
# #**Mean, Variance and Standard Deviation**

# %%
# Mean, Variance and Std-deviation
print("Means:")
print(np.mean(iris_satosa["PetalLengthCm"]))

# Mean with Outlier.
print(np.mean(np.append(iris_satosa["PetalLengthCm"], 50)))

print(np.mean(iris_virginica["PetalLengthCm"]))
print(np.mean(iris_versicolor["PetalLengthCm"]))

print("\nStd-deviation:")
print(np.std(iris_satosa["PetalLengthCm"]))
print(np.std(iris_virginica["PetalLengthCm"]))
print(np.std(iris_versicolor["PetalLengthCm"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.552
# 4.26
#
# Std-deviation:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %% [markdown]
# #**Median, Percentile, Quantile, IQR, MAD**

# %%
# Median, Percentile, Quantile, IQR
print("\nMedian:")

print(np.median(iris_satosa["PetalLengthCm"]))

# Median with a Outlier.
print(np.median(np.append(iris_satosa["PetalLengthCm"], 50)))

print(np.median(iris_virginica["PetalLengthCm"]))
print(np.median(iris_versicolor["PetalLengthCm"]))

print("\nQuantiles:")
print(np.percentile(iris_satosa["PetalLengthCm"], np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["PetalLengthCm"], np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["PetalLengthCm"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_satosa["PetalLengthCm"], 90))
print(np.percentile(iris_virginica["PetalLengthCm"], 90))
print(np.percentile(iris_versicolor["PetalLengthCm"], 90))
# Out:
# Median:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.3100000000000005
# 4.8

# %%
from statsmodels import robust
print("\nMedian Absolute Deviation:")
print(robust.mad(iris_satosa["PetalLengthCm"]))
print(robust.mad(iris_virginica["PetalLengthCm"]))
print(robust.mad(iris_versicolor["PetalLengthCm"]))
# Out:
# Median Absolute Deviation:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# #**Box Plot and Whiskers**

# %%
sn.boxplot(x="Species", y="PetalLengthCm", data=iris)
plt.show()

# %% [markdown]
# #**Violin Plot**

# %%
sn.violinplot(x="Species", y="PetalLengthCm", data=iris, size=8)
plt.show()

# %% [markdown]
# #**Multivariate probability density, contour plot.**

# %%
# 2D Density plot, contors-plot
sn.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_satosa, kind="kde", size=8)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
